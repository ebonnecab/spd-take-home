# %%
#import packages
import pandas as pd
import csv
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## *Step 1*: Read the data into a pandas dataframe for data manipulation and analyis

# %%
df = pd.read_csv('Crime_Data.csv')
df.head(10)
# Out:
#     Report Number Occurred Date  Occurred Time Reported Date  Reported Time  \
# 0   1975000079415    12/16/1975          900.0    12/16/1975         1500.0
# 1   1976000069169    01/01/1976            1.0    01/31/1976         2359.0
# 2   1979000049118    01/28/1979         1600.0    02/09/1979         1430.0
# 3  19810000305573    08/22/1981         2029.0    08/22/1981         2030.0
# 4   1981000076456    02/14/1981         2000.0    02/15/1981          435.0
# 5  19880000507482    09/29/1988          155.0    09/29/1988          155.0
# 6  19930000465323    10/08/1993         2213.0    10/08/1993         2213.0
# 7  19940000264046    06/08/1994            0.0    06/12/1994          844.0
# 8  19960000543964    12/08/1996         1130.0    12/08/1996         1700.0
# 9  19990000333737           NaN            NaN    01/01/1999            NaN
#
#       Crime Subcategory   Primary Offense Description   Precinct Sector Beat  \
# 0  BURGLARY-RESIDENTIAL            BURGLARY-FORCE-RES      SOUTH      R   R3
# 1     SEX OFFENSE-OTHER     SEXOFF-INDECENT LIBERTIES    UNKNOWN    NaN  NaN
# 2             CAR PROWL                THEFT-CARPROWL       EAST      G   G2
# 3              HOMICIDE  HOMICIDE-PREMEDITATED-WEAPON      SOUTH      S   S2
# 4  BURGLARY-RESIDENTIAL            BURGLARY-FORCE-RES  SOUTHWEST      W   W3
# 5   MOTOR VEHICLE THEFT                VEH-THEFT-AUTO       WEST      M   M2
# 6              HOMICIDE     HOMICIDE-PREMEDITATED-GUN      SOUTH      R   R2
# 7       THEFT-ALL OTHER                     THEFT-OTH  SOUTHWEST      F   F1
# 8             CAR PROWL                THEFT-CARPROWL      SOUTH      O   O1
# 9        THEFT-SHOPLIFT                THEFT-SHOPLIFT    UNKNOWN    NaN  NaN
#
#                      Neighborhood
# 0            LAKEWOOD/SEWARD PARK
# 1                         UNKNOWN
# 2        CENTRAL AREA/SQUIRE PARK
# 3                 BRIGHTON/DUNLAP
# 4  ROXHILL/WESTWOOD/ARBOR HEIGHTS
# 5                     SLU/CASCADE
# 6         CLAREMONT/RAINIER VISTA
# 7                      HIGH POINT
# 8                            SODO
# 9                         UNKNOWN

# %% [markdown]
# ## *Step 2*: Clean and examine the data for a more accurate analysis

# %%
#get column names
column_names = df.columns
print(column_names)
# Out:
# Index([u'Report Number', u'Occurred Date', u'Occurred Time', u'Reported Date',
#        u'Reported Time', u'Crime Subcategory', u'Primary Offense Description',
#        u'Precinct', u'Sector', u'Beat', u'Neighborhood'],
#       dtype='object')

# %%
#get column datatypes
df.dtypes
# Out:
# Report Number                    int64
# Occurred Date                   object
# Occurred Time                  float64
# Reported Date                   object
# Reported Time                  float64
# Crime Subcategory               object
# Primary Offense Description     object
# Precinct                        object
# Sector                          object
# Beat                            object
# Neighborhood                    object
# dtype: object

# %%
#drop columns I don't plan on using
df = df.drop(['Occurred Time', 'Reported Time', 'Sector', 'Beat'], axis=1)

# %%
df.head()
# Out:
#     Report Number Occurred Date Reported Date     Crime Subcategory  \
# 0   1975000079415    12/16/1975    12/16/1975  BURGLARY-RESIDENTIAL
# 1   1976000069169    01/01/1976    01/31/1976     SEX OFFENSE-OTHER
# 2   1979000049118    01/28/1979    02/09/1979             CAR PROWL
# 3  19810000305573    08/22/1981    08/22/1981              HOMICIDE
# 4   1981000076456    02/14/1981    02/15/1981  BURGLARY-RESIDENTIAL
#
#     Primary Offense Description   Precinct                    Neighborhood
# 0            BURGLARY-FORCE-RES      SOUTH            LAKEWOOD/SEWARD PARK
# 1     SEXOFF-INDECENT LIBERTIES    UNKNOWN                         UNKNOWN
# 2                THEFT-CARPROWL       EAST        CENTRAL AREA/SQUIRE PARK
# 3  HOMICIDE-PREMEDITATED-WEAPON      SOUTH                 BRIGHTON/DUNLAP
# 4            BURGLARY-FORCE-RES  SOUTHWEST  ROXHILL/WESTWOOD/ARBOR HEIGHTS

# %%
#reexamining the dataframe after dropping those columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523590 entries, 0 to 523589
# Data columns (total 7 columns):
# Report Number                  523590 non-null int64
# Occurred Date                  523588 non-null object
# Reported Date                  523590 non-null object
# Crime Subcategory              523328 non-null object
# Primary Offense Description    523590 non-null object
# Precinct                       523584 non-null object
# Neighborhood                   523590 non-null object
# dtypes: int64(1), object(6)
# memory usage: 28.0+ MB

# %% [markdown]
# **From my observation, we have a lot of categorial data to work with.**

# %%
#looking for duplicate rows (there are none)
duplicatesdf = df[df.duplicated()]
print(duplicatesdf)
# Out:
# Empty DataFrame
# Columns: [Report Number, Occurred Date, Reported Date, Crime Subcategory, Primary Offense Description, Precinct, Neighborhood]
# Index: []

# %%
#checking if any columns contain na values
df.isna().any()
# Out:
# Report Number                  False
# Occurred Date                   True
# Reported Date                  False
# Crime Subcategory               True
# Primary Offense Description    False
# Precinct                        True
# Neighborhood                   False
# dtype: bool

# %%
#dropping rows with NaN values
df = df.dropna()

# %%
#change column names for easier data manipulation
df=df.rename(columns = {'Report Number':'report_num', 'Occurred Date':'occurred_date',
                        'Reported Date':'reported_date', 'Crime Subcategory':'crime_subcategory',
                       'Primary Offense Description':'primary_offense_descript'})

# %%
#showing array of unique Precincts
df.Precinct.unique()
# Out:
# array(['SOUTH', 'UNKNOWN', 'EAST', 'SOUTHWEST', 'WEST', 'NORTH'],
#       dtype=object)

# %%
#showing array of unique Neighborhoods
df.Neighborhood.unique()
# Out:
# array(['LAKEWOOD/SEWARD PARK', 'UNKNOWN', 'CENTRAL AREA/SQUIRE PARK',
#        'BRIGHTON/DUNLAP', 'ROXHILL/WESTWOOD/ARBOR HEIGHTS', 'SLU/CASCADE',
#        'CLAREMONT/RAINIER VISTA', 'HIGH POINT', 'SODO',
#        'DOWNTOWN COMMERCIAL', 'FIRST HILL',
#        'JUDKINS PARK/NORTH BEACON HILL', 'NORTH ADMIRAL', 'MILLER PARK',
#        'HILLMAN CITY', 'MORGAN', 'SOUTH PARK', 'MONTLAKE/PORTAGE BAY',
#        'CAPITOL HILL', 'NORTHGATE', 'LAKECITY', 'NEW HOLLY',
#        'RAINIER BEACH', 'QUEEN ANNE', 'RAINIER VIEW', 'BELLTOWN',
#        'ROOSEVELT/RAVENNA', 'ALASKA JUNCTION', 'GREENWOOD',
#        'PIONEER SQUARE', 'NORTH BEACON HILL', 'GEORGETOWN',
#        'SOUTH DELRIDGE', 'HIGHLAND PARK', 'BITTERLAKE', 'MOUNT BAKER',
#        'MADRONA/LESCHI', 'COLUMBIA CITY', 'NORTH DELRIDGE', 'FREMONT',
#        'MID BEACON HILL', 'BALLARD NORTH', 'BALLARD SOUTH',
#        'PHINNEY RIDGE', 'SANDPOINT', 'MAGNOLIA', 'UNIVERSITY',
#        'CHINATOWN/INTERNATIONAL DISTRICT', 'WALLINGFORD',
#        'EASTLAKE - WEST', 'SOUTH BEACON HILL', 'ALKI', 'FAUNTLEROY SW',
#        'PIGEON POINT', 'MADISON PARK', 'GENESEE',
#        'COMMERCIAL HARBOR ISLAND', 'EASTLAKE - EAST',
#        'COMMERCIAL DUWAMISH'], dtype=object)

# %%
#showing unique crime subcategories
df.crime_subcategory.unique()
# Out:
# array(['BURGLARY-RESIDENTIAL', 'SEX OFFENSE-OTHER', 'CAR PROWL',
#        'HOMICIDE', 'MOTOR VEHICLE THEFT', 'THEFT-ALL OTHER', 'DUI',
#        'AGGRAVATED ASSAULT-DV', 'RAPE', 'AGGRAVATED ASSAULT',
#        'ROBBERY-STREET', 'BURGLARY-COMMERCIAL', 'THEFT-BICYCLE',
#        'NARCOTIC', 'PROSTITUTION', 'ARSON', 'PORNOGRAPHY',
#        'ROBBERY-COMMERCIAL', 'FAMILY OFFENSE-NONVIOLENT',
#        'THEFT-SHOPLIFT', 'WEAPON', 'THEFT-BUILDING',
#        'ROBBERY-RESIDENTIAL', 'TRESPASS', 'LIQUOR LAW VIOLATION',
#        'DISORDERLY CONDUCT', 'GAMBLE', 'LOITERING',
#        'BURGLARY-COMMERCIAL-SECURE PARKING',
#        'BURGLARY-RESIDENTIAL-SECURE PARKING'], dtype=object)

# %%
#showing unique primary offenses assigned to each report
df.primary_offense_descript.unique()
# Out:
# array(['BURGLARY-FORCE-RES', 'SEXOFF-INDECENT LIBERTIES',
#        'THEFT-CARPROWL', 'HOMICIDE-PREMEDITATED-WEAPON', 'VEH-THEFT-AUTO',
#        'HOMICIDE-PREMEDITATED-GUN', 'THEFT-OTH', 'DUI-LIQUOR',
#        'ASSLT-AGG-DV-BODYFORCE', 'RAPE-STRONGARM', 'SEXOFF-OTHER',
#        'ASSLT-AGG-GUN', 'ROBBERY-STREET-BODYFORCE',
#        'ASSLT-AGG-POLICE-GUN', 'ASSLT-AGG-WEAPON',
#        'BURGLARY-FORCE-NONRES', 'HOMICIDE-PREMEDITATED-BODYFORCE',
#        'BURGLARY-NOFORCE-RES', 'VEH-THEFT-MTRCYCLE', 'THEFT-PKPOCKET',
#        'THEFT-BICYCLE', 'NARC-POSSESS-MARIJU', 'PROSTITUTION',
#        'ARSON-VEHICLE', 'ASSLT-AGG-CHILD-BODYFORCE',
#        'PORNOGRAPHY-OBSCENE MATERIAL', 'ROBBERY-STREET-GUN',
#        'SEXOFF-PEEPER', 'ROBBERY-BANK-BODYFORCE',
#        'ROBBERY-BUSINESS-BODYFORCE', 'ROBBERY-BUSINESS-WEAPON',
#        'ASSLT-AGG-DV-WEAPON', 'THEFT-LICENSE PLATE', 'CHILD-OTHER',
#        'SEXOFF-OTHER OBJECT', 'ROBBERY-BUSINESS-GUN',
#        'ASSLT-AGG-BODYFORCE', 'NARC-POSSESS-COCAINE',
#        'ASSLT-AGG-POLICE-BODYFORCE', 'SEXOFF-INDECENT EXPOSURE',
#        'CHILD-ABUSED-NOFORCE', 'NARC-POSSESS-OTHER', 'VEH-THEFT-TRUCK',
#        'THEFT-SHOPLIFT', 'WEAPON-POSSESSION', 'SEXOFF-SODOMY',
#        'THEFT-BUILDING', 'ROBBERY-RESIDENCE-GUN', 'THEFT-AUTOACC',
#        'TRESPASS', 'THEFT-PRSNATCH', 'BURGLARY-NOFORCE-NONRES',
#        'THEFT-COINOP', 'NARC-EQUIPMENT/PARAPHENALIA', 'NARC-SELL-COCAINE',
#        'NARC-POSSESS-METH', 'LIQUOR LAW VIOLATION',
#        'HARBOR - BOATING UNDER INFLUENCE', 'WEAPON-DISCHARGE',
#        'NARC-SELL-METH', 'NARC-POSSESS-HEROIN',
#        'PROSTITUTION-ASSIST-PROMOTE', 'CHILD-ENDANGERMENT',
#        'VEH-THEFT-TRAILER', 'ARSON-OTHER', 'ARSON-BUSINESS',
#        'WEAPON-UNLAWFUL USE', 'NARC-PRODUCE-MARIJU',
#        'ROBBERY-RESIDENCE-BODYFORCE', 'ROBBERY-STREET-WEAPON',
#        'NARC-SELL-MARIJU', 'ROBBERY-RESIDENCE-WEAPON',
#        'DISORDERLY CONDUCT', 'PROSTITUTION LOITERING',
#        'NARC-DRUG TRAFFIC LOITERING', 'NARC-SELL-AMPHETAMINE',
#        'SEXOFF-LEWD CONDUCT', 'NARC-FORGERY-PRESCRIPTION',
#        'WEAPON-CONCEALED', 'CHILD-ABANDON', 'NARC-POSSESS-AMPHETAMINE',
#        'NARC-SELL-HEROIN', 'DUI-DRUGS', 'ROBBERY-BANK-OTHER',
#        'NARC-POSSESS-PILL/TABLET', 'CHILD-NEGLECT',
#        'NARC-POSSESS-HALLUCINOGEN', 'ASSLT-AGG-DV-GUN', 'RAPE-OTHER',
#        'NARC-FRAUD-PRESCRIPTION', 'NARC-SELL-OTHER',
#        'VEH-THEFT-RECREATION VEH', 'NARC-DISTRIBUTE-HALLUCINOGEN',
#        'NARC-MANUFACTURE-OTHER', 'ROBBERY-BANK-GUN', 'VEH-THEFT-OTHVEH',
#        'CHILD-HARBOR MINOR', 'ARSON-RESIDENCE', 'VEH-THEFT-HVYEQUIP',
#        'THEFT-BOAT', 'GAMBLE-BETTING', 'PROSTITUTION PATRONIZING',
#        'NARC-POSSESS-BARBITUATE', 'LOITERING', 'RAPE-WEAPON',
#        'INTERFERE WITH REPORT-DV', 'NARC-POSSESS-PRESCRIPTION',
#        'RAPE-GUN', 'NARC-SELL-PRESCRIPTION', 'NARC-SELL-PILL/TABLET',
#        'ASSLT-AGG-POLICE-WEAPON', 'NARC-POSSESS-OPIUM', 'GAMBLE-OPERATE',
#        'HOMICIDE-NEG-MANS-GUN', 'NARC-SMUGGLE-MARIJU',
#        'NARC-SMUGGLE-COCAINE', 'NARC-POSSESS-SYNTHETIC',
#        'NARC-SELL-SYNTHETIC', 'NARC-SELL-HALLUCINOGEN',
#        'ROBBERY-BANK-WEAPON', 'HOMICIDE-NEG-MANS-VEHICLE',
#        'HUMAN-TRAFFICKING-SEX', 'NARC-SMUGGLE-HEROIN',
#        'SEX ABUSE MINOR-COMMERCIAL', 'BURGLARY-SECURE PARKING-NONRES',
#        'BURGLARY-SECURE PARKING-RES', 'NARC-SELL-OPIUM',
#        'NARC-SMUGGLE-METH', 'NARC-MANUFACTURE-METH', 'THEFT-AUTO PARTS',
#        'ADULT-VULNERABLE-PHYSICAL ABUSE', 'THEFT-MAIL', 'ENDANGERMENT',
#        'ADULT-VULNERABLE-NEGLECT', 'ADULT-VULNERABLE-FINANCIAL',
#        'VEH-THEFT-BUS', 'HOMICIDE-NEG-MANS-BODYFORCE',
#        'SEX ABUSE MINOR-PROMO COMMERC', 'NARC-SMUGGLE-OTHER',
#        'NARC-SELL-BARBITUATE', 'NARC-MANUFACTURE-HALLUCINOGEN',
#        'HOMICIDE-NEG-MANS-WEAPON'], dtype=object)

# %% [markdown]
# ## *Step 3*: Time to start analyzing the data we have left for patterns and information about crime in Seattle.

# %% [markdown]
# How many reports are there for each crime subcategory?

# %%
print(df['crime_subcategory'].value_counts())
# Out:
# CAR PROWL                              148263
# THEFT-ALL OTHER                         54419
# THEFT-SHOPLIFT                          48637
# BURGLARY-RESIDENTIAL                    46843
# MOTOR VEHICLE THEFT                     43526
# BURGLARY-COMMERCIAL                     23531
# THEFT-BUILDING                          21437
# TRESPASS                                17722
# NARCOTIC                                17380
# AGGRAVATED ASSAULT                      15640
# DUI                                     12837
# ROBBERY-STREET                          11882
# THEFT-BICYCLE                           11091
# BURGLARY-RESIDENTIAL-SECURE PARKING      8852
# AGGRAVATED ASSAULT-DV                    6922
# FAMILY OFFENSE-NONVIOLENT                6855
# SEX OFFENSE-OTHER                        6396
# WEAPON                                   4987
# ROBBERY-COMMERCIAL                       4660
# PROSTITUTION                             3609
# RAPE                                     2022
# LIQUOR LAW VIOLATION                     1651
# BURGLARY-COMMERCIAL-SECURE PARKING       1164
# ARSON                                    1071
# ROBBERY-RESIDENTIAL                      1062
# DISORDERLY CONDUCT                        283
# HOMICIDE                                  275
# PORNOGRAPHY                               195
# LOITERING                                  91
# GAMBLE                                     17
# Name: crime_subcategory, dtype: int64
# 523320

# %%
crime_count = df['crime_subcategory'].value_counts()
plt.figure(figsize=(10,5))
sns.set(style="darkgrid")
chart = sns.barplot(crime_count.index, crime_count.values, alpha=0.9)
plt.title('Frequency Distribution of Crimes')
plt.ylabel('Number of Occurences', fontsize=12)
plt.xlabel('Crime', fontsize=12)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# How does the type of crime vary by Precinct?

# %%
neighborhood_df = pd.crosstab(df["crime_subcategory"], df["Precinct"])
neighborhood_df
# Out:
# Precinct                              EAST  NORTH  SOUTH  SOUTHWEST  UNKNOWN  \
# crime_subcategory
# AGGRAVATED ASSAULT                    2697   3738   2726       1264      158
# AGGRAVATED ASSAULT-DV                 1105   1835   1837       1032       58
# ARSON                                  145    369    215        137        4
# BURGLARY-COMMERCIAL                   2967   8190   3559       2119       32
# BURGLARY-COMMERCIAL-SECURE PARKING     195    270     43         53        1
# BURGLARY-RESIDENTIAL                  6910  18264  10035       6403       70
# BURGLARY-RESIDENTIAL-SECURE PARKING   2044   3467    112        511        7
# CAR PROWL                            20853  48222  18671      13195      662
# DISORDERLY CONDUCT                      41     45     34         12        1
# DUI                                   2118   3973   2019       1277      121
# FAMILY OFFENSE-NONVIOLENT             1138   2085   1426       1027      155
# GAMBLE                                   4      1      7          1        0
# HOMICIDE                                47     45     83         31        0
# LIQUOR LAW VIOLATION                   281    407    213        118       16
# LOITERING                                6      8      9          7        1
# MOTOR VEHICLE THEFT                   5751  16570   8487       5787       84
# NARCOTIC                              2658   2622   2050        711      455
# PORNOGRAPHY                             32     32     13         26       20
# PROSTITUTION                            93   1947    222         60      115
# RAPE                                   341    545    284        177      192
# ROBBERY-COMMERCIAL                     577   1531    719        421        5
# ROBBERY-RESIDENTIAL                    165    314    290        125        4
# ROBBERY-STREET                        2030   2396   2789        816      133
# SEX OFFENSE-OTHER                     1118   1751    885        683      377
# THEFT-ALL OTHER                       8588  17588   7339       5778      419
# THEFT-BICYCLE                         2000   4655    699        723       23
# THEFT-BUILDING                        4187   5829   2351       1668       42
# THEFT-SHOPLIFT                        4588  15525   4180       3554       30
# TRESPASS                              3885   5050   2000       1125       61
# WEAPON                                 870   1022   1095        470       95
#
# Precinct                              WEST
# crime_subcategory
# AGGRAVATED ASSAULT                    5057
# AGGRAVATED ASSAULT-DV                 1055
# ARSON                                  201
# BURGLARY-COMMERCIAL                   6664
# BURGLARY-COMMERCIAL-SECURE PARKING     602
# BURGLARY-RESIDENTIAL                  5161
# BURGLARY-RESIDENTIAL-SECURE PARKING   2711
# CAR PROWL                            46660
# DISORDERLY CONDUCT                     150
# DUI                                   3329
# FAMILY OFFENSE-NONVIOLENT             1024
# GAMBLE                                   4
# HOMICIDE                                69
# LIQUOR LAW VIOLATION                   616
# LOITERING                               60
# MOTOR VEHICLE THEFT                   6847
# NARCOTIC                              8884
# PORNOGRAPHY                             72
# PROSTITUTION                          1172
# RAPE                                   483
# ROBBERY-COMMERCIAL                    1407
# ROBBERY-RESIDENTIAL                    164
# ROBBERY-STREET                        3718
# SEX OFFENSE-OTHER                     1582
# THEFT-ALL OTHER                      14707
# THEFT-BICYCLE                         2991
# THEFT-BUILDING                        7360
# THEFT-SHOPLIFT                       20760
# TRESPASS                              5601
# WEAPON                                1435

# %% [markdown]
# Creating a dictionary to encode crime subcategories into numeric values.

# %%
labels = df['crime_subcategory'].astype('category').cat.categories.tolist()
replace_map = {'crime_subcategory' : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}

# %%
print(replace_map)
